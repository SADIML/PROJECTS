# %% [markdown]
# # install dependancies, takes around 45 seconds
#
# Rendering Dependancies

# %%
#remove " > /dev/null 2>&1" to see what is going on under the hood
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# %% [markdown]
# Pacman Dependancies

# %%
# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# !pip install gym[all] > /dev/null 2>&1
# Out:
# Requirement already up-to-date: setuptools in /usr/local/lib/python3.6/dist-packages (46.1.3)

# %% [markdown]
# # Imports and Helper functions

# %%
import gym
from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) #error only
import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
import copy
from collections import namedtuple, deque

# %matplotlib inline
import math
import glob
import io
import base64
from IPython.display import HTML

from IPython import display as ipythondisplay
import os
import torch 
import torch.nn as nn
import torch.nn.functional as tn
import numpy as np
from torch.autograd import Variable
import torch.optim as optim
import copy

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# xdpyinfo was not found, X start can not be checked! Please install xdpyinfo!
# <Display cmd_param=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1400x900x24', ':1005'] cmd=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1400x900x24', ':1005'] oserror=None return_code=None stdout="None" stderr="None" timeout_happened=False>

# %%
"""
Utility functions to enable video recording of gym environment and displaying it
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %% [markdown]
# # **LUNARLANDER**

# %%
env = wrap_env(gym.make("LunarLanderContinuous-v2"))

# %%
observation = env.reset()

while True:
  
    env.render()
    
    #your agent goes here
    action = env.action_space.sample() 
  
         
    observation, reward, done, info = env.step(action) 
   
        
    if done: 
      break;
            
env.close()
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
print(type(observation))
observation = torch.from_numpy(observation)
print(observation)
print(observation.size()[0])
# Out:
# <class 'numpy.ndarray'>
# tensor([ 0.5590, -0.0370,  0.2242, -0.4995,  0.2297,  3.9077,  1.0000,  1.0000])
# 8

# %% [markdown]
# # **ACTOR MODEL**

# %%
HID_LAYER1 = 128
HID_LAYER2 = 64

actiondim=env.action_space.shape[0]


class Actor(nn.Module):

  def __init__(self,env,name,chkpt_dir='tmp/ddpg'):
    super(Actor,self).__init__()
    observation = env.reset()
    observation = torch.from_numpy(observation)
    #saving the learnable parameters
    self.checkpoint_file = os.path.join(chkpt_dir,name+'_ddpg')

    #There are 3 layers input ,1 hidden,output

    #input is state observations 
    self.lin1 = nn.Linear(observation.size()[0],HID_LAYER1)
    self.batchnorm1 = nn.BatchNorm1d(HID_LAYER1)
    
    self.lin2 = nn.Linear(HID_LAYER1,HID_LAYER2)
    self.batchnorm2 = nn.BatchNorm1d(HID_LAYER2)
    
    #output is actions
    self.lin3 = nn.Linear(HID_LAYER2,actiondim)
    
    #Activation layers
    self.ReLU = nn.ReLU()
    #self.softmax = tn.softmax()
    self.Tanh = nn.Tanh()

  def forward(self,input1):
    #ip_norm = self.norm0(ip)
    h1 = self.ReLU(self.lin1(input1))
    #h1_norm = self.batchnorm1(h1)
    h2 = self.ReLU(self.lin2(h1))
    #h2_norm = self.batchnorm2(h2)
    action = self.Tanh((self.lin3(h2)))
    #actions = tn.softmax(actions)

    return action

  def save_checkpoint(self):
      print('... saving checkpoint ...')
      T.save(self.state_dict(), self.checkpoint_file)

  def load_checkpoint(self):
      print('... loading checkpoint ...')
      self.load_state_dict(T.load(self.checkpoint_file))

# %% [markdown]
# # **CRITIC MODEL**

# %%
HID_LAYER1 = 128
HID_LAYER2 = 64

class critic(nn.Module):

  def __init__(self,env,name,chkpt_dir='tmp/ddpg'):
    super(critic,self).__init__()
    observation = env.reset()
    observation = torch.from_numpy(observation)
    actiondim=env.action_space.shape[0]
    #saving the learnable parameters
    self.checkpoint_file = os.path.join(chkpt_dir,name+'_ddpg')


    
    #There are 3 layers input ,1 hidden,output

    #input is state observations 
    self.lin1 = nn.Linear(observation.size()[0],HID_LAYER1)
    self.batchnorm1 = nn.BatchNorm1d(HID_LAYER1)
    
    self.lin2 = nn.Linear(HID_LAYER1+actiondim,HID_LAYER2)
    self.batchnorm2 = nn.BatchNorm1d(HID_LAYER2)
    
    #output is actions
    self.lin3 = nn.Linear(HID_LAYER2,1)
    
    #Activation layers
    self.ReLU = nn.ReLU()
    self.Tanh = nn.Tanh()

  def forward(self,action,input1):
    #ip_norm = self.norm0(ip)                            
    h1 = self.ReLU(self.lin1(input1))
    h1_norm = self.batchnorm1(h1)
    x = torch.cat((h1_norm,action),1)
    h2 = self.ReLU(self.lin2(x))
    qvalue = self.lin3(h2)
    return qvalue


  def save_checkpoint(self):
      print('... saving checkpoint ...')
      T.save(self.state_dict(), self.checkpoint_file)

  def load_checkpoint(self):
      print('... loading checkpoint ...')
      self.load_state_dict(T.load(self.checkpoint_file))

# %% [markdown]
# # **Replay Buffer**

# %%
class rbuffer(object):
  def __init__(self,buffer_size):
    self.buffer_size = buffer_size
    self.position = 0
    self.memory = []
  
  def reset(self):
    self.position = 0
    self.memory = []
  
  def length(self):
    return len(self.memory)

  def push(self,batch):
    if len(self.memory) < self.buffer_size:
            self.memory.append(None)
    self.memory[self.position] = batch
    self.position = (self.position + 1) % self.buffer_size

  
  def sample_batch(self,batchSize):
    #if len(self.memory) == self.buffer_size:
    batch = random.sample(self.memory, batchSize)
    curState = [element[0] for element in batch]
    action = [element[1] for element in batch]
    nextState = [element[2] for element in batch]
    reward = [element[3] for element in batch]
    terminal = [element[4] for element in batch]
    # print('here')
    #   print(batch)
    return curState, action, nextState, reward, terminal

# %% [markdown]
# # **NOISE**

# %%
import numpy as np


class AdaptiveParamNoiseSpec(object):
    def __init__(self, initial_stddev=0.1, desired_action_stddev=0.1, adoption_coefficient=1.01):
        self.initial_stddev = initial_stddev
        self.desired_action_stddev = desired_action_stddev
        self.adoption_coefficient = adoption_coefficient

        self.current_stddev = initial_stddev

    def adapt(self, distance):
        if distance > self.desired_action_stddev:
            # Decrease stddev.
            self.current_stddev /= self.adoption_coefficient
        else:
            # Increase stddev.
            self.current_stddev *= self.adoption_coefficient

    def get_stats(self):
        stats = {
            'param_noise_stddev': self.current_stddev,
        }
        return stats

    def __repr__(self):
        fmt = 'AdaptiveParamNoiseSpec(initial_stddev={}, desired_action_stddev={}, adoption_coefficient={})'
        return fmt.format(self.initial_stddev, self.desired_action_stddev, self.adoption_coefficient)


class ActionNoise(object):
    def reset(self):
        pass


class NormalActionNoise(ActionNoise):
    def __init__(self, m=0, sigma=0.25):
        self.mu = mu
        self.sigma = sigma

    def __call__(self):
        return np.random.normal(self.mu, self.sigma)

    def __repr__(self):
        return 'NormalActionNoise(mu={}, sigma={})'.format(self.mu, self.sigma)

# %%
class OUNoise:
    """Ornstein-Uhlenbeck process."""

    def __init__(self, size, seed=0, mu=0., theta=0.15, sigma=0.3):
        """Initialize parameters and noise process."""
        self.mu = mu * np.ones(size)
        self.theta = theta
        self.sigma = sigma
        self.seed = random.seed(seed)
        self.reset()

    def reset(self):
        """Reset the internal state (= noise) to mean (mu)."""
        self.state = copy.copy(self.mu)

    def sample(self):
        """Update internal state and return it as a noise sample."""
        x = self.state
        dx = self.theta * (self.mu - x) + self.sigma * np.array([random.random() for i in range(len(x))])
        self.state = x + dx
        return self.state

# %% [markdown]
# # **DDPG AGENT**

# %%
# Hyperparameters for DDPG Algorithm
ACTOR_LR = 0.0001
CRITIC_LR = 0.001
MINIBATCH_SIZE = 64
NUM_EPISODES = 10000
MU = 0
SIGMA = 0.2
CHECKPOINT_DIR = './checkpoints/manipulator/'
BUFFER_SIZE = 1000000
DISCOUNT = 0.9
TAU = 0.001
WARMUP = 100
EPSILON = 0.4
EPSILON_DECAY = 1e-6
action_size = env.action_space.shape[0]
epsodereward=[]
Temp = 0

class DDPG_Agent(object):
  def __init__(self,env):
    self.env=env
    self.actor = Actor(self.env,name='Actor')
    self.critic = critic(self.env,name='Critic')
    self.targetactor = copy.deepcopy(Actor(self.env,name='targetActor'))
    self.targetcritic = copy.deepcopy(critic(self.env,name='targetCritic'))
    self.actor_Optim = optim.Adam(self.actor.parameters(), lr=ACTOR_LR)
    self.critic_Optim = optim.Adam(self.critic.parameters(), lr=CRITIC_LR)
    self.criticLoss = nn.MSELoss()
    self.replayBuffer = rbuffer(BUFFER_SIZE)
    self.batchSize = MINIBATCH_SIZE
    self.checkpoint_dir = CHECKPOINT_DIR
    self.discount = DISCOUNT
    self.Temp = Temp
    self.warmup = WARMUP
    self.epsilon = EPSILON
    self.noise = NormalActionNoise()
    self.epsilon_decay = EPSILON_DECAY

  def maxaction(self,curstate,add_noise=True):
    state = torch.from_numpy(curstate).float()

    self.actor.eval()
    with torch.no_grad():
        action = self.actor(state).cpu().data.numpy()
    self.actor.train()
    
    if add_noise:
        action += self.epsilon * self.noise.__call__()

    return action

  def qvaluelabel(self,nextstate,reward,done):
    nextaction = self.targetactor(nextstate)
    next_q=self.targetcritic(nextaction,nextstate)
    #If the episode ends then need to see if
    done = torch.ByteTensor(done)
    reward = torch.from_numpy(np.array(reward))
    target_q = reward + self.discount*(1-done)*next_q

    return target_q

  def replaybuffer1(self):
    count = 0
    observation = env.reset()
    if self.replayBuffer.length() >= self.warmup:
      pass
    else:
      while count<101:
        if np.random.sample() > self.epsilon:
          count+=1
          currstate = observation

          #your agent goes here
          action = self.maxaction(currstate)
          observation, reward, done, info = env.step(action)

          nextstate = observation
          reward = reward
          action = action
          terminal = done
          self.replayBuffer.push((currstate,action,nextstate,reward,terminal))
        else:
          count+=1
          currstate = observation

          #your agent goes here
          action = env.action_space.sample()
          observation, reward, done, info = env.step(action)

          nextstate = observation
          reward = reward
          action = action
          terminal = done
          self.replayBuffer.push((currstate,action,nextstate,reward,terminal))

  def updateTargets(self, target, original):
        """Weighted average update of the target network and original network
            Inputs: target actor(critic) and original actor(critic)"""
        
        for targetParam, orgParam in zip(target.parameters(), original.parameters()):
            targetParam.data.copy_((1 - TAU)*targetParam.data +  TAU*orgParam.data)

  def learn(self):
      self.Temp+=1
      if self.Temp % 20 == 0:
        self.replayBuffer.reset()

      if self.replayBuffer.length()>=100:
          pass
      else:
          self.replaybuffer1()
        
      currstate,action,nextstate,reward,terminal = self.replayBuffer.sample_batch(self.batchSize)
      currstate = torch.from_numpy(np.array(currstate))
      nextstate = torch.from_numpy(np.array(nextstate))
      action = torch.from_numpy(np.array(action))


      target_q = self.qvaluelabel(nextstate.float(), reward, terminal)
      #action = torch.from_numpy(action)
      qpredicted = self.critic(action.float(),currstate.float())

      #criticupdate
      self.critic_Optim.zero_grad()
      criticloss = self.criticLoss(target_q,qpredicted)
      criticloss.backward()
      self.critic_Optim.step()

      #actorupdate
      self.actor_Optim.zero_grad()
      action1 = self.actor(currstate.float())
      actorloss = -torch.mean(self.critic(action1,currstate.float() ))
      actorloss.backward()
      self.actor_Optim.step()

      #update target
      # self.update_network_parameters()

      self.updateTargets(self.targetcritic, self.critic)
      self.updateTargets(self.targetactor, self.actor)

# %%
agent=DDPG_Agent(env)

# %%
from google.colab import files

# %%
import time
def ddpg(n_episodes=10000, max_t=2000, print_every=5):
    scores_deque = deque(maxlen=print_every)
    scores = []
  
    for i_episode in range(1, n_episodes+1):
        
        state = env.reset()
        
        #agent.reset()
        score = 0
        timestep = time.time()
        for t in range(max_t):
            action = agent.maxaction(state)
            #env.render()
            action = np.clip(action, -1, 1)
            next_state, reward, done, _ = env.step(action)
            
            agent.learn()
            state = next_state
            score += reward
            if done:
                break 
                
        scores_deque.append(score)
        scores.append(score)
        score_average = np.mean(scores_deque)
        
        if i_episode % print_every == 0:
            print('\rEpisode {}, Average Score: {:.2f}, Max score: {:.2f}, Min score: {:.2f}, Time: {:.2f}'\
                  .format(i_episode, score_average, np.max(scores), np.min(scores), time.time() - timestep), end="\n")
                    
        if np.mean(scores_deque)>90.0:            
            torch.save(agent.actor.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.critic.state_dict(), 'checkpoint_critic.pth')
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode, score_average))            
            break            
            
            
    return scores

scores = ddpg()

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score') 
plt.xlabel('Episode #')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/loss.py:432: UserWarning: Using a target size (torch.Size([64, 1])) that is different to the input size (torch.Size([64, 64])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Episode 5, Average Score: -136.25, Max score: -97.05, Min score: -172.57, Time: 0.27
# Episode 10, Average Score: -141.92, Max score: -97.05, Min score: -178.57, Time: 0.28
# Episode 15, Average Score: -158.69, Max score: -95.47, Min score: -235.53, Time: 0.34
# Episode 20, Average Score: -152.70, Max score: -95.47, Min score: -235.53, Time: 0.29
# Episode 25, Average Score: -212.76, Max score: -95.47, Min score: -339.77, Time: 0.51
# Episode 30, Average Score: -264.21, Max score: -95.47, Min score: -443.63, Time: 0.95
# Episode 35, Average Score: -244.98, Max score: -95.47, Min score: -503.54, Time: 0.81
# Episode 40, Average Score: -289.99, Max score: -95.47, Min score: -574.53, Time: 0.50
# Episode 45, Average Score: -223.01, Max score: -95.47, Min score: -574.53, Time: 0.15
# Episode 50, Average Score: -147.49, Max score: -95.47, Min score: -574.53, Time: 0.29
# Episode 55, Average Score: -312.54, Max score: -95.47, Min score: -900.22, Time: 0.26
# Episode 60, Average Score: -186.49, Max score: -95.00, Min score: -900.22, Time: 0.34
# Episode 65, Average Score: -276.08, Max score: -95.00, Min score: -900.22, Time: 0.42
# Episode 70, Average Score: -148.72, Max score: -94.11, Min score: -900.22, Time: 0.27
# Episode 75, Average Score: -186.57, Max score: -94.11, Min score: -900.22, Time: 0.26
# Episode 80, Average Score: -192.13, Max score: -94.11, Min score: -900.22, Time: 0.41
# Episode 85, Average Score: -305.14, Max score: -94.11, Min score: -900.22, Time: 0.27
# Episode 90, Average Score: -147.32, Max score: -79.44, Min score: -900.22, Time: 0.26
# Episode 95, Average Score: -220.12, Max score: -63.17, Min score: -900.22, Time: 0.39
# Episode 100, Average Score: -225.60, Max score: -63.17, Min score: -900.22, Time: 0.28
# Episode 105, Average Score: -230.65, Max score: -63.17, Min score: -900.22, Time: 0.27
# Episode 110, Average Score: -312.44, Max score: -63.17, Min score: -900.22, Time: 0.39
# Episode 115, Average Score: -268.12, Max score: -63.17, Min score: -900.22, Time: 0.27
# Episode 120, Average Score: -222.98, Max score: -63.17, Min score: -900.22, Time: 0.13
# Episode 125, Average Score: -281.15, Max score: -63.17, Min score: -900.22, Time: 0.12
# Episode 130, Average Score: -171.55, Max score: -63.17, Min score: -900.22, Time: 0.27
# Episode 135, Average Score: -266.11, Max score: -63.17, Min score: -900.22, Time: 0.37
# Episode 140, Average Score: -249.93, Max score: -63.17, Min score: -900.22, Time: 0.26
# Episode 145, Average Score: -317.38, Max score: -63.17, Min score: -900.22, Time: 0.15
# Episode 150, Average Score: -356.95, Max score: -63.17, Min score: -900.22, Time: 0.35
# Episode 155, Average Score: -203.98, Max score: -63.17, Min score: -900.22, Time: 0.10
# Episode 160, Average Score: -134.55, Max score: -63.17, Min score: -900.22, Time: 0.26
# Episode 165, Average Score: -184.74, Max score: -63.17, Min score: -900.22, Time: 0.27
# Episode 170, Average Score: -284.10, Max score: 43.51, Min score: -953.83, Time: 0.29
# Episode 175, Average Score: -243.02, Max score: 43.51, Min score: -953.83, Time: 0.53
# Episode 180, Average Score: -198.05, Max score: 43.51, Min score: -953.83, Time: 0.27
# Episode 185, Average Score: -264.21, Max score: 43.51, Min score: -953.83, Time: 0.22
# Episode 190, Average Score: -246.47, Max score: 43.51, Min score: -953.83, Time: 0.28
# Episode 195, Average Score: -298.47, Max score: 43.51, Min score: -953.83, Time: 0.31
# Episode 200, Average Score: -292.56, Max score: 43.51, Min score: -953.83, Time: 0.55
# Episode 205, Average Score: -235.78, Max score: 43.51, Min score: -953.83, Time: 0.25
# Episode 210, Average Score: -338.68, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 215, Average Score: -245.21, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 220, Average Score: -219.89, Max score: 43.51, Min score: -992.00, Time: 0.31
# Episode 225, Average Score: -235.55, Max score: 43.51, Min score: -992.00, Time: 0.34
# Episode 230, Average Score: -177.82, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 235, Average Score: -149.64, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 240, Average Score: -263.64, Max score: 43.51, Min score: -992.00, Time: 0.55
# Episode 245, Average Score: -351.30, Max score: 43.51, Min score: -992.00, Time: 0.51
# Episode 250, Average Score: -190.39, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 255, Average Score: -244.71, Max score: 43.51, Min score: -992.00, Time: 0.30
# Episode 260, Average Score: -377.53, Max score: 43.51, Min score: -992.00, Time: 0.30
# Episode 265, Average Score: -227.01, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 270, Average Score: -233.64, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 275, Average Score: -198.47, Max score: 43.51, Min score: -992.00, Time: 0.55
# Episode 280, Average Score: -226.36, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 285, Average Score: -261.17, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 290, Average Score: -185.25, Max score: 43.51, Min score: -992.00, Time: 0.17
# Episode 295, Average Score: -264.33, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 300, Average Score: -164.14, Max score: 43.51, Min score: -992.00, Time: 0.36
# Episode 305, Average Score: -157.74, Max score: 43.51, Min score: -992.00, Time: 0.30
# Episode 310, Average Score: -282.48, Max score: 43.51, Min score: -992.00, Time: 0.52
# Episode 315, Average Score: -335.79, Max score: 43.51, Min score: -992.00, Time: 0.52
# Episode 320, Average Score: -198.45, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 325, Average Score: -319.74, Max score: 43.51, Min score: -992.00, Time: 0.10
# Episode 330, Average Score: -181.32, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 335, Average Score: -146.17, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 340, Average Score: -302.36, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 345, Average Score: -284.65, Max score: 43.51, Min score: -992.00, Time: 0.53
# Episode 350, Average Score: -171.11, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 355, Average Score: -163.99, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 360, Average Score: -129.19, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 365, Average Score: -221.29, Max score: 43.51, Min score: -992.00, Time: 0.54
# Episode 370, Average Score: -177.50, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 375, Average Score: -249.34, Max score: 43.51, Min score: -992.00, Time: 0.09
# Episode 380, Average Score: -185.58, Max score: 43.51, Min score: -992.00, Time: 0.32
# Episode 385, Average Score: -213.96, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 390, Average Score: -272.32, Max score: 43.51, Min score: -992.00, Time: 0.56
# Episode 395, Average Score: -248.56, Max score: 43.51, Min score: -992.00, Time: 0.44
# Episode 400, Average Score: -165.04, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 405, Average Score: -268.94, Max score: 43.51, Min score: -992.00, Time: 0.45
# Episode 410, Average Score: -390.97, Max score: 43.51, Min score: -992.00, Time: 0.55
# Episode 415, Average Score: -196.66, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 420, Average Score: -233.00, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 425, Average Score: -388.47, Max score: 43.51, Min score: -992.00, Time: 0.55
# Episode 430, Average Score: -209.06, Max score: 43.51, Min score: -992.00, Time: 0.30
# Episode 435, Average Score: -327.26, Max score: 43.51, Min score: -992.00, Time: 0.52
# Episode 440, Average Score: -331.20, Max score: 43.51, Min score: -992.00, Time: 0.54
# Episode 445, Average Score: -165.57, Max score: 43.51, Min score: -992.00, Time: 0.30
# Episode 450, Average Score: -214.10, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 455, Average Score: -171.64, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 460, Average Score: -157.06, Max score: 43.51, Min score: -992.00, Time: 0.31
# Episode 465, Average Score: -196.19, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 470, Average Score: -157.49, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 475, Average Score: -173.77, Max score: 43.51, Min score: -992.00, Time: 0.18
# Episode 480, Average Score: -227.95, Max score: 43.51, Min score: -992.00, Time: 0.30
# Episode 485, Average Score: -269.80, Max score: 43.51, Min score: -992.00, Time: 0.33
# Episode 490, Average Score: -278.57, Max score: 43.51, Min score: -992.00, Time: 0.52
# Episode 495, Average Score: -247.73, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 500, Average Score: -139.23, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 505, Average Score: -170.96, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 510, Average Score: -179.96, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 515, Average Score: -213.50, Max score: 43.51, Min score: -992.00, Time: 0.14
# Episode 520, Average Score: -172.11, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 525, Average Score: -230.00, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 530, Average Score: -128.49, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 535, Average Score: -148.14, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 540, Average Score: -144.30, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 545, Average Score: -151.43, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 550, Average Score: -146.16, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 555, Average Score: -152.74, Max score: 43.51, Min score: -992.00, Time: 0.30
# Episode 560, Average Score: -147.32, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 565, Average Score: -164.56, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 570, Average Score: -136.04, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 575, Average Score: -144.12, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 580, Average Score: -165.07, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 585, Average Score: -162.28, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 590, Average Score: -153.30, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 595, Average Score: -155.54, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 600, Average Score: -143.64, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 605, Average Score: -156.05, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 610, Average Score: -119.47, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 615, Average Score: -151.65, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 620, Average Score: -142.26, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 625, Average Score: -147.47, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 630, Average Score: -142.55, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 635, Average Score: -137.79, Max score: 43.51, Min score: -992.00, Time: 0.29
# Episode 640, Average Score: -130.74, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 645, Average Score: -166.26, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 650, Average Score: -160.77, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 655, Average Score: -174.37, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 660, Average Score: -147.95, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 665, Average Score: -153.06, Max score: 43.51, Min score: -992.00, Time: 0.29
# Episode 670, Average Score: -161.69, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 675, Average Score: -154.48, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 680, Average Score: -138.10, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 685, Average Score: -150.47, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 690, Average Score: -171.72, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 695, Average Score: -147.54, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 700, Average Score: -153.33, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 705, Average Score: -138.07, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 710, Average Score: -144.31, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 715, Average Score: -151.43, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 720, Average Score: -163.65, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 725, Average Score: -153.34, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 730, Average Score: -174.26, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 735, Average Score: -162.06, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 740, Average Score: -147.69, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 745, Average Score: -162.88, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 750, Average Score: -145.42, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 755, Average Score: -146.09, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 760, Average Score: -132.94, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 765, Average Score: -169.74, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 770, Average Score: -168.27, Max score: 43.51, Min score: -992.00, Time: 0.34
# Episode 775, Average Score: -139.34, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 780, Average Score: -160.00, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 785, Average Score: -153.61, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 790, Average Score: -147.29, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 795, Average Score: -162.15, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 800, Average Score: -156.52, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 805, Average Score: -129.33, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 810, Average Score: -147.41, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 815, Average Score: -148.28, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 820, Average Score: -143.34, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 825, Average Score: -158.56, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 830, Average Score: -130.43, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 835, Average Score: -155.67, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 840, Average Score: -154.36, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 845, Average Score: -137.22, Max score: 43.51, Min score: -992.00, Time: 0.31
# Episode 850, Average Score: -176.10, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 855, Average Score: -178.60, Max score: 43.51, Min score: -992.00, Time: 0.53
# Episode 860, Average Score: -159.44, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 865, Average Score: -153.61, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 870, Average Score: -172.24, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 875, Average Score: -138.70, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 880, Average Score: -131.13, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 885, Average Score: -158.87, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 890, Average Score: -161.14, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 895, Average Score: -151.24, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 900, Average Score: -130.07, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 905, Average Score: -143.73, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 910, Average Score: -149.67, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 915, Average Score: -152.67, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 920, Average Score: -165.27, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 925, Average Score: -128.07, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 930, Average Score: -125.62, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 935, Average Score: -151.63, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 940, Average Score: -133.72, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 945, Average Score: -107.96, Max score: 43.51, Min score: -992.00, Time: 0.23
# Episode 950, Average Score: -114.10, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 955, Average Score: -109.99, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 960, Average Score: -112.72, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 965, Average Score: -110.32, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 970, Average Score: -132.32, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 975, Average Score: -131.00, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 980, Average Score: -141.08, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 985, Average Score: -150.25, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 990, Average Score: -135.71, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 995, Average Score: -131.50, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1000, Average Score: -138.44, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1005, Average Score: -143.36, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1010, Average Score: -132.92, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1015, Average Score: -133.59, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1020, Average Score: -118.02, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1025, Average Score: -133.37, Max score: 43.51, Min score: -992.00, Time: 0.29
# Episode 1030, Average Score: -129.24, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1035, Average Score: -138.42, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1040, Average Score: -140.39, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1045, Average Score: -123.92, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1050, Average Score: -149.30, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1055, Average Score: -106.33, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1060, Average Score: -115.44, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1065, Average Score: -117.32, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1070, Average Score: -127.73, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1075, Average Score: -118.04, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1080, Average Score: -142.37, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1085, Average Score: -140.12, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1090, Average Score: -129.10, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1095, Average Score: -152.99, Max score: 43.51, Min score: -992.00, Time: 0.29
# Episode 1100, Average Score: -119.19, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1105, Average Score: -143.06, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1110, Average Score: -109.40, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1115, Average Score: -142.66, Max score: 43.51, Min score: -992.00, Time: 0.16
# Episode 1120, Average Score: -149.27, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1125, Average Score: -143.87, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1130, Average Score: -123.80, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1135, Average Score: -151.55, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1140, Average Score: -127.15, Max score: 43.51, Min score: -992.00, Time: 0.32
# Episode 1145, Average Score: -148.88, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1150, Average Score: -130.88, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1155, Average Score: -148.38, Max score: 43.51, Min score: -992.00, Time: 0.31
# Episode 1160, Average Score: -127.46, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1165, Average Score: -116.67, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1170, Average Score: -146.90, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1175, Average Score: -135.86, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1180, Average Score: -126.27, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1185, Average Score: -128.30, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 1190, Average Score: -144.08, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1195, Average Score: -142.05, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1200, Average Score: -123.23, Max score: 43.51, Min score: -992.00, Time: 0.32
# Episode 1205, Average Score: -133.27, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1210, Average Score: -140.71, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1215, Average Score: -167.64, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1220, Average Score: -136.32, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1225, Average Score: -132.79, Max score: 43.51, Min score: -992.00, Time: 0.29
# Episode 1230, Average Score: -137.42, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1235, Average Score: -142.69, Max score: 43.51, Min score: -992.00, Time: 0.21
# Episode 1240, Average Score: -125.31, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1245, Average Score: -122.18, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1250, Average Score: -128.48, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 1255, Average Score: -117.85, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1260, Average Score: -111.62, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1265, Average Score: -137.68, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1270, Average Score: -123.59, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1275, Average Score: -132.62, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 1280, Average Score: -127.36, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1285, Average Score: -120.69, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1290, Average Score: -145.96, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 1295, Average Score: -125.27, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1300, Average Score: -133.64, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1305, Average Score: -112.81, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1310, Average Score: -143.11, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1315, Average Score: -139.32, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1320, Average Score: -118.12, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1325, Average Score: -125.87, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1330, Average Score: -125.48, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1335, Average Score: -126.39, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1340, Average Score: -147.25, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1345, Average Score: -129.42, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1350, Average Score: -114.98, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1355, Average Score: -126.66, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1360, Average Score: -122.35, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1365, Average Score: -150.40, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1370, Average Score: -134.71, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1375, Average Score: -132.13, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1380, Average Score: -138.99, Max score: 43.51, Min score: -992.00, Time: 0.15
# Episode 1385, Average Score: -138.64, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1390, Average Score: -131.14, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1395, Average Score: -123.06, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1400, Average Score: -124.04, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1405, Average Score: -132.91, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1410, Average Score: -126.36, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1415, Average Score: -120.69, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1420, Average Score: -136.39, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 1425, Average Score: -141.62, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1430, Average Score: -137.26, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1435, Average Score: -129.27, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1440, Average Score: -133.46, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1445, Average Score: -114.14, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1450, Average Score: -133.47, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1455, Average Score: -114.68, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1460, Average Score: -126.96, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1465, Average Score: -125.97, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1470, Average Score: -115.89, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1475, Average Score: -123.84, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1480, Average Score: -138.73, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1485, Average Score: -140.16, Max score: 43.51, Min score: -992.00, Time: 0.30
# Episode 1490, Average Score: -121.40, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1495, Average Score: -126.70, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1500, Average Score: -114.54, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1505, Average Score: -136.61, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1510, Average Score: -141.00, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1515, Average Score: -129.25, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1520, Average Score: -150.47, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1525, Average Score: -126.78, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 1530, Average Score: -124.82, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1535, Average Score: -120.52, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1540, Average Score: -118.37, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1545, Average Score: -124.41, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1550, Average Score: -147.58, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1555, Average Score: -125.52, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1560, Average Score: -125.78, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1565, Average Score: -130.79, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 1570, Average Score: -136.71, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1575, Average Score: -130.27, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1580, Average Score: -118.72, Max score: 43.51, Min score: -992.00, Time: 0.29
# Episode 1585, Average Score: -134.71, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1590, Average Score: -122.02, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1595, Average Score: -129.18, Max score: 43.51, Min score: -992.00, Time: 0.29
# Episode 1600, Average Score: -138.91, Max score: 43.51, Min score: -992.00, Time: 0.33
# Episode 1605, Average Score: -146.22, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 1610, Average Score: -139.50, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1615, Average Score: -151.45, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1620, Average Score: -117.65, Max score: 43.51, Min score: -992.00, Time: 0.29
# Episode 1625, Average Score: -129.54, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 1630, Average Score: -138.95, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1635, Average Score: -136.86, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1640, Average Score: -131.40, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1645, Average Score: -149.11, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 1650, Average Score: -131.82, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1655, Average Score: -133.33, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1660, Average Score: -136.31, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1665, Average Score: -146.75, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1670, Average Score: -131.06, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 1675, Average Score: -145.30, Max score: 43.51, Min score: -992.00, Time: 0.29
# Episode 1680, Average Score: -124.46, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 1685, Average Score: -132.84, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1690, Average Score: -112.84, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 1695, Average Score: -130.86, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1700, Average Score: -112.57, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 1705, Average Score: -109.37, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1710, Average Score: -140.10, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1715, Average Score: -153.42, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1720, Average Score: -136.34, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 1725, Average Score: -134.97, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1730, Average Score: -130.82, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1735, Average Score: -127.72, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1740, Average Score: -122.11, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1745, Average Score: -137.86, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1750, Average Score: -144.89, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1755, Average Score: -139.78, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1760, Average Score: -144.18, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1765, Average Score: -129.15, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1770, Average Score: -136.93, Max score: 43.51, Min score: -992.00, Time: 0.29
# Episode 1775, Average Score: -131.04, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1780, Average Score: -137.35, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1785, Average Score: -119.86, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1790, Average Score: -116.87, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1795, Average Score: -112.31, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1800, Average Score: -135.21, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1805, Average Score: -144.76, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 1810, Average Score: -127.09, Max score: 43.51, Min score: -992.00, Time: 0.21
# Episode 1815, Average Score: -132.73, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1820, Average Score: -139.98, Max score: 43.51, Min score: -992.00, Time: 0.37
# Episode 1825, Average Score: -123.09, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1830, Average Score: -120.14, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1835, Average Score: -136.41, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 1840, Average Score: -127.33, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1845, Average Score: -127.28, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1850, Average Score: -131.47, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1855, Average Score: -138.52, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1860, Average Score: -120.64, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1865, Average Score: -133.49, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1870, Average Score: -140.71, Max score: 43.51, Min score: -992.00, Time: 0.32
# Episode 1875, Average Score: -133.42, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1880, Average Score: -134.70, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1885, Average Score: -125.31, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1890, Average Score: -130.97, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 1895, Average Score: -135.76, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1900, Average Score: -135.13, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1905, Average Score: -122.01, Max score: 43.51, Min score: -992.00, Time: 0.23
# Episode 1910, Average Score: -136.17, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1915, Average Score: -125.56, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1920, Average Score: -135.45, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1925, Average Score: -125.28, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1930, Average Score: -121.62, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1935, Average Score: -123.38, Max score: 43.51, Min score: -992.00, Time: 0.31
# Episode 1940, Average Score: -130.09, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1945, Average Score: -128.89, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1950, Average Score: -120.29, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1955, Average Score: -135.41, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1960, Average Score: -131.22, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1965, Average Score: -152.87, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1970, Average Score: -126.54, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1975, Average Score: -131.50, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1980, Average Score: -126.06, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1985, Average Score: -148.04, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 1990, Average Score: -139.25, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 1995, Average Score: -130.66, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2000, Average Score: -134.78, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2005, Average Score: -125.32, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 2010, Average Score: -147.23, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2015, Average Score: -132.68, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2020, Average Score: -134.92, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2025, Average Score: -119.08, Max score: 43.51, Min score: -992.00, Time: 0.23
# Episode 2030, Average Score: -119.44, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2035, Average Score: -129.14, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2040, Average Score: -142.09, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2045, Average Score: -136.59, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 2050, Average Score: -112.07, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2055, Average Score: -131.53, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2060, Average Score: -173.00, Max score: 43.51, Min score: -992.00, Time: 0.10
# Episode 2065, Average Score: -123.77, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2070, Average Score: -138.58, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2075, Average Score: -106.99, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2080, Average Score: -124.19, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 2085, Average Score: -153.08, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2090, Average Score: -133.66, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2095, Average Score: -107.11, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2100, Average Score: -138.22, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2105, Average Score: -130.98, Max score: 43.51, Min score: -992.00, Time: 0.23
# Episode 2110, Average Score: -102.39, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 2115, Average Score: -140.82, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2120, Average Score: -139.96, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2125, Average Score: -134.98, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2130, Average Score: -128.52, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2135, Average Score: -128.70, Max score: 43.51, Min score: -992.00, Time: 0.23
# Episode 2140, Average Score: -104.61, Max score: 43.51, Min score: -992.00, Time: 0.16
# Episode 2145, Average Score: -131.96, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2150, Average Score: -122.88, Max score: 43.51, Min score: -992.00, Time: 0.29
# Episode 2155, Average Score: -121.62, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2160, Average Score: -132.56, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2165, Average Score: -134.12, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 2170, Average Score: -139.86, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2175, Average Score: -133.90, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2180, Average Score: -141.22, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2185, Average Score: -121.39, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 2190, Average Score: -139.65, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2195, Average Score: -130.10, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2200, Average Score: -122.18, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2205, Average Score: -141.14, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2210, Average Score: -114.27, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2215, Average Score: -126.86, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2220, Average Score: -143.81, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2225, Average Score: -142.50, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2230, Average Score: -109.46, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2235, Average Score: -136.12, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2240, Average Score: -135.59, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2245, Average Score: -137.05, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2250, Average Score: -117.76, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2255, Average Score: -144.31, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2260, Average Score: -145.26, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 2265, Average Score: -118.57, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2270, Average Score: -124.54, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2275, Average Score: -128.69, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2280, Average Score: -140.53, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2285, Average Score: -132.35, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2290, Average Score: -118.30, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2295, Average Score: -148.43, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2300, Average Score: -128.03, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2305, Average Score: -117.75, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 2310, Average Score: -114.83, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2315, Average Score: -124.94, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2320, Average Score: -130.74, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2325, Average Score: -129.43, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2330, Average Score: -131.26, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2335, Average Score: -120.39, Max score: 43.51, Min score: -992.00, Time: 0.23
# Episode 2340, Average Score: -141.23, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2345, Average Score: -146.94, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 2350, Average Score: -138.36, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2355, Average Score: -134.73, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2360, Average Score: -126.18, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 2365, Average Score: -118.65, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2370, Average Score: -140.74, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2375, Average Score: -142.12, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2380, Average Score: -127.86, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2385, Average Score: -137.62, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 2390, Average Score: -150.28, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 2395, Average Score: -134.74, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2400, Average Score: -122.98, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 2405, Average Score: -120.26, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2410, Average Score: -110.44, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2415, Average Score: -136.66, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2420, Average Score: -119.39, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2425, Average Score: -126.91, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2430, Average Score: -123.00, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2435, Average Score: -133.35, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2440, Average Score: -134.03, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2445, Average Score: -144.06, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2450, Average Score: -121.53, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2455, Average Score: -129.82, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2460, Average Score: -118.59, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2465, Average Score: -122.10, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2470, Average Score: -139.90, Max score: 43.51, Min score: -992.00, Time: 0.29
# Episode 2475, Average Score: -133.17, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 2480, Average Score: -132.89, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2485, Average Score: -128.67, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2490, Average Score: -134.75, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2495, Average Score: -109.57, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2500, Average Score: -144.64, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2505, Average Score: -113.07, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2510, Average Score: -135.51, Max score: 43.51, Min score: -992.00, Time: 0.19
# Episode 2515, Average Score: -134.40, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 2520, Average Score: -125.29, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2525, Average Score: -115.78, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2530, Average Score: -125.70, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2535, Average Score: -135.67, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2540, Average Score: -124.56, Max score: 43.51, Min score: -992.00, Time: 0.21
# Episode 2545, Average Score: -124.86, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2550, Average Score: -137.33, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2555, Average Score: -147.80, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2560, Average Score: -103.73, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2565, Average Score: -134.09, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2570, Average Score: -119.72, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2575, Average Score: -138.51, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2580, Average Score: -144.20, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2585, Average Score: -128.47, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2590, Average Score: -124.92, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2595, Average Score: -139.01, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2600, Average Score: -130.15, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2605, Average Score: -130.46, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2610, Average Score: -145.09, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2615, Average Score: -138.87, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2620, Average Score: -144.51, Max score: 43.51, Min score: -992.00, Time: 0.18
# Episode 2625, Average Score: -148.93, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2630, Average Score: -136.10, Max score: 43.51, Min score: -992.00, Time: 0.22
# Episode 2635, Average Score: -126.52, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2640, Average Score: -120.89, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2645, Average Score: -133.52, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 2650, Average Score: -144.75, Max score: 43.51, Min score: -992.00, Time: 0.14
# Episode 2655, Average Score: -112.81, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2660, Average Score: -140.07, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2665, Average Score: -124.50, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2670, Average Score: -159.95, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2675, Average Score: -114.98, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2680, Average Score: -127.27, Max score: 43.51, Min score: -992.00, Time: 0.17
# Episode 2685, Average Score: -124.75, Max score: 43.51, Min score: -992.00, Time: 0.28
# Episode 2690, Average Score: -130.58, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2695, Average Score: -107.55, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2700, Average Score: -136.77, Max score: 43.51, Min score: -992.00, Time: 0.27
# Episode 2705, Average Score: -126.27, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2710, Average Score: -127.97, Max score: 43.51, Min score: -992.00, Time: 0.24
# Episode 2715, Average Score: -131.55, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2720, Average Score: -145.03, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2725, Average Score: -126.77, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2730, Average Score: -136.89, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2735, Average Score: -149.57, Max score: 43.51, Min score: -992.00, Time: 0.26
# Episode 2740, Average Score: -137.69, Max score: 43.51, Min score: -992.00, Time: 0.25
# Episode 2745, Average Score: -164.97, Max score: 43.51, Min score: -992.00, Time: 0.25
# ...
# Episode 9090, Average Score: -129.24, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9095, Average Score: -152.33, Max score: 50.40, Min score: -992.00, Time: 0.28
# Episode 9100, Average Score: -153.28, Max score: 50.40, Min score: -992.00, Time: 0.30
# Episode 9105, Average Score: -140.26, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9110, Average Score: -134.02, Max score: 50.40, Min score: -992.00, Time: 0.28
# Episode 9115, Average Score: -121.28, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9120, Average Score: -118.03, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9125, Average Score: -152.98, Max score: 50.40, Min score: -992.00, Time: 0.29
# Episode 9130, Average Score: -163.32, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9135, Average Score: -147.57, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9140, Average Score: -136.81, Max score: 50.40, Min score: -992.00, Time: 0.35
# Episode 9145, Average Score: -150.88, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9150, Average Score: -148.87, Max score: 50.40, Min score: -992.00, Time: 0.33
# Episode 9155, Average Score: -146.47, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9160, Average Score: -151.50, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9165, Average Score: -151.17, Max score: 50.40, Min score: -992.00, Time: 0.28
# Episode 9170, Average Score: -121.27, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9175, Average Score: -156.98, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9180, Average Score: -143.92, Max score: 50.40, Min score: -992.00, Time: 0.35
# Episode 9185, Average Score: -140.77, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9190, Average Score: -123.53, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9195, Average Score: -142.56, Max score: 50.40, Min score: -992.00, Time: 0.28
# Episode 9200, Average Score: -156.17, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9205, Average Score: -115.90, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9210, Average Score: -139.08, Max score: 50.40, Min score: -992.00, Time: 0.28
# Episode 9215, Average Score: -135.48, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9220, Average Score: -139.10, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9225, Average Score: -120.52, Max score: 50.40, Min score: -992.00, Time: 0.28
# Episode 9230, Average Score: -125.45, Max score: 50.40, Min score: -992.00, Time: 0.29
# Episode 9235, Average Score: -130.98, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9240, Average Score: -124.19, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9245, Average Score: -126.89, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9250, Average Score: -141.32, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9255, Average Score: -124.61, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9260, Average Score: -124.92, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9265, Average Score: -133.52, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9270, Average Score: -129.90, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9275, Average Score: -136.29, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9280, Average Score: -124.13, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9285, Average Score: -121.89, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9290, Average Score: -130.04, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9295, Average Score: -134.47, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9300, Average Score: -124.04, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9305, Average Score: -121.39, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9310, Average Score: -111.43, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9315, Average Score: -117.13, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9320, Average Score: -94.39, Max score: 50.40, Min score: -992.00, Time: 0.53
# Episode 9325, Average Score: -127.75, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9330, Average Score: -133.21, Max score: 50.40, Min score: -992.00, Time: 0.28
# Episode 9335, Average Score: -146.77, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9340, Average Score: -137.67, Max score: 50.40, Min score: -992.00, Time: 0.29
# Episode 9345, Average Score: -135.80, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9350, Average Score: -131.94, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9355, Average Score: -136.37, Max score: 50.40, Min score: -992.00, Time: 0.28
# Episode 9360, Average Score: -142.51, Max score: 50.40, Min score: -992.00, Time: 0.28
# Episode 9365, Average Score: -127.15, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9370, Average Score: -138.94, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9375, Average Score: -138.03, Max score: 50.40, Min score: -992.00, Time: 0.28
# Episode 9380, Average Score: -121.16, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9385, Average Score: -108.06, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9390, Average Score: -133.62, Max score: 50.40, Min score: -992.00, Time: 0.29
# Episode 9395, Average Score: -148.36, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9400, Average Score: -104.28, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9405, Average Score: -129.36, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9410, Average Score: -134.01, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9415, Average Score: -121.95, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9420, Average Score: -136.55, Max score: 50.40, Min score: -992.00, Time: 0.31
# Episode 9425, Average Score: -134.00, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9430, Average Score: -129.36, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9435, Average Score: -126.43, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9440, Average Score: -174.23, Max score: 50.40, Min score: -992.00, Time: 0.34
# Episode 9445, Average Score: -111.54, Max score: 50.40, Min score: -992.00, Time: 0.31
# Episode 9450, Average Score: -113.78, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9455, Average Score: -130.96, Max score: 50.40, Min score: -992.00, Time: 0.29
# Episode 9460, Average Score: -121.11, Max score: 50.40, Min score: -992.00, Time: 0.28
# Episode 9465, Average Score: -127.64, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9470, Average Score: -126.15, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9475, Average Score: -113.74, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9480, Average Score: -136.48, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9485, Average Score: -168.05, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9490, Average Score: -126.32, Max score: 50.40, Min score: -992.00, Time: 0.41
# Episode 9495, Average Score: -130.01, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9500, Average Score: -136.47, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9505, Average Score: -126.09, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9510, Average Score: -114.74, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9515, Average Score: -125.51, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9520, Average Score: -118.16, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9525, Average Score: -141.66, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9530, Average Score: -147.69, Max score: 50.40, Min score: -992.00, Time: 0.28
# Episode 9535, Average Score: -127.46, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9540, Average Score: -138.10, Max score: 50.40, Min score: -992.00, Time: 0.32
# Episode 9545, Average Score: -115.64, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9550, Average Score: -143.30, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9555, Average Score: -134.65, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9560, Average Score: -128.92, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9565, Average Score: -120.28, Max score: 50.40, Min score: -992.00, Time: 0.28
# Episode 9570, Average Score: -105.04, Max score: 50.40, Min score: -992.00, Time: 0.29
# Episode 9575, Average Score: -112.62, Max score: 50.40, Min score: -992.00, Time: 0.23
# Episode 9580, Average Score: -133.69, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9585, Average Score: -134.42, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9590, Average Score: -137.46, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9595, Average Score: -133.34, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9600, Average Score: -133.66, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9605, Average Score: -140.02, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9610, Average Score: -115.36, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9615, Average Score: -138.10, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9620, Average Score: -136.43, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9625, Average Score: -135.19, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9630, Average Score: -116.59, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9635, Average Score: -120.83, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9640, Average Score: -129.77, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9645, Average Score: -125.98, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9650, Average Score: -143.33, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9655, Average Score: -151.06, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9660, Average Score: -114.19, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9665, Average Score: -115.39, Max score: 50.40, Min score: -992.00, Time: 0.28
# Episode 9670, Average Score: -119.01, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9675, Average Score: -143.57, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9680, Average Score: -133.94, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9685, Average Score: -137.52, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9690, Average Score: -124.99, Max score: 50.40, Min score: -992.00, Time: 0.28
# Episode 9695, Average Score: -108.17, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9700, Average Score: -121.00, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9705, Average Score: -121.10, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9710, Average Score: -114.97, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9715, Average Score: -111.87, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9720, Average Score: -128.58, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9725, Average Score: -122.46, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9730, Average Score: -123.54, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9735, Average Score: -132.94, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9740, Average Score: -120.92, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9745, Average Score: -125.46, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9750, Average Score: -121.34, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9755, Average Score: -150.55, Max score: 50.40, Min score: -992.00, Time: 0.21
# Episode 9760, Average Score: -131.67, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9765, Average Score: -108.87, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9770, Average Score: -121.66, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9775, Average Score: -120.18, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9780, Average Score: -120.60, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9785, Average Score: -118.91, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9790, Average Score: -137.54, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9795, Average Score: -116.45, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9800, Average Score: -134.50, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9805, Average Score: -121.72, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9810, Average Score: -122.57, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9815, Average Score: -127.50, Max score: 50.40, Min score: -992.00, Time: 0.23
# Episode 9820, Average Score: -129.16, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9825, Average Score: -117.39, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9830, Average Score: -108.97, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9835, Average Score: -122.41, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9840, Average Score: -119.15, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9845, Average Score: -121.56, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9850, Average Score: -118.21, Max score: 50.40, Min score: -992.00, Time: 0.30
# Episode 9855, Average Score: -123.14, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9860, Average Score: -125.41, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9865, Average Score: -180.32, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9870, Average Score: -133.62, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9875, Average Score: -135.79, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9880, Average Score: -122.98, Max score: 50.40, Min score: -992.00, Time: 0.28
# Episode 9885, Average Score: -137.43, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9890, Average Score: -119.33, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9895, Average Score: -136.34, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9900, Average Score: -146.52, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9905, Average Score: -133.33, Max score: 50.40, Min score: -992.00, Time: 0.30
# Episode 9910, Average Score: -127.92, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9915, Average Score: -114.48, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9920, Average Score: -133.62, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9925, Average Score: -129.46, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9930, Average Score: -134.58, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9935, Average Score: -129.23, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9940, Average Score: -139.14, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9945, Average Score: -132.66, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9950, Average Score: -134.17, Max score: 50.40, Min score: -992.00, Time: 0.22
# Episode 9955, Average Score: -126.42, Max score: 50.40, Min score: -992.00, Time: 0.25
# Episode 9960, Average Score: -137.00, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9965, Average Score: -133.69, Max score: 50.40, Min score: -992.00, Time: 0.31
# Episode 9970, Average Score: -119.13, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9975, Average Score: -131.45, Max score: 50.40, Min score: -992.00, Time: 0.27
# Episode 9980, Average Score: -133.54, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9985, Average Score: -129.84, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 9990, Average Score: -140.50, Max score: 50.40, Min score: -992.00, Time: 0.26
# Episode 9995, Average Score: -155.67, Max score: 50.40, Min score: -992.00, Time: 0.24
# Episode 10000, Average Score: -123.71, Max score: 50.40, Min score: -992.00, Time: 0.24
